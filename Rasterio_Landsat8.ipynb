    # Download the file if it does not exist already
    if not os.path.exists(outfp):
        print("Downloading", fname)
        r = urllib.request.urlretrieve(url, outfp)

# %%
import rasterio
#import rsgislib
#from rsgislib import imageutils

# %%
fd = "C:/Users/mac/Documents/Python_Rasterio"

# %%
# Create list of images
imageList = ['LC08_L1TP_169056_20190312_20190325_01_T1_B1.TIF',
             'LC08_L1TP_169056_20190312_20190325_01_T1_B2.TIF',
             'LC08_L1TP_169056_20190312_20190325_01_T1_B3.TIF',
             'LC08_L1TP_169056_20190312_20190325_01_T1_B4.TIF',
             'LC08_L1TP_169056_20190312_20190325_01_T1_B5.TIF',
             'LC08_L1TP_169056_20190312_20190325_01_T1_B6.TIF',
             'LC08_L1TP_169056_20190312_20190325_01_T1_B7.TIF',
            'LC08_L1TP_169056_20190312_20190325_01_T1_B9.TIF',
            'LC08_L1TP_169056_20190312_20190325_01_T1_B10.TIF',
            'LC08_L1TP_169056_20190312_20190325_01_T1_B11.TIF']

# %%
# Set format and type
#gdalFormat = 'GTiff'
#dataType = rsgislib.TYPE_16UINT
# Stack
#imageutils.stackImageBands(imageList, bandNamesList, outputImage, None, 0, gdalFormat, dataType)

# %%
# Open the file:
#raster = rasterio.open(fp)

# %%
import os

landsat_scene_name = "LC08_L1TP_169056_20190312_20190325_01_T1"

nir_path = os.path.join("C:/Users/mac/Documents/Python_Rasterio/", 
                        "{}_B5.TIF".format(landsat_scene_name))
red_path = os.path.join("C:/Users/mac/Documents/Python_Rasterio/", 
                        "{}_B4.TIF".format(landsat_scene_name))
green_path = os.path.join("C:/Users/home/hadoop/data/", 
                       "{}_B3.TIF".format(landsat_scene_name))
blue_path = os.path.join("C:/Users/home/hadoop/data/", 
                       "{}_B2.TIF".format(landsat_scene_name))

# %% [markdown]
# Then we call ds.read() to read the data as a numpy array, without capturing any other metadata from the DatasetReader.

# %%
import rasterio

with rasterio.open(red_path) as ds:
    red_data = ds.read()

# %% [markdown]
# red_data is a numpy ndarray containing the raster values of the red band of our Landsat scene. An ndarray is an N-Dimensional Array, which can be thought of as an N dimensional matrix. If we look at the "shape" of the array, we can see that it has 3 dimensions:

# %%
red_data.shape
# Out:
# (1, 7761, 7601)

# %% [markdown]
# shape returns a tuple that shows the size of each dimension. This raster data has length 1 at the first dimension, because that dimension represents the band of the raster - this is a single band raster, so there is only 2D image in this ndarray. If we read in a 3 band raster, fo instance, this might read something like (3, 761, 7611). The second and third lenghts are the number of rows and columns in the image, respectively.

# %% [markdown]
# ### Visualizing the red band
# One of the first things we'll want to do with raster data is visualize it. This is only a single band of Landsat, so at first we'll just create a grayscale image.
#
# We'll be using matplotlib, which is a great library to use in combination with Jupyter notebooks in order to visualize your data. A lot of matplotlib is about creating charts and graphs, but it can also show images. This snippet of code will render our raster as grayscale. Notice we are indexing into the 3D array to pull out the 2D image that is the first (and only) band:

# %%
import matplotlib.pyplot as plt

plt.imshow(red_data[0], cmap='gray')
plt.show()

# %% [markdown]
# Notice this image is dark. That's because Landsat data is stored in the uint16 data type, which has a range of values from 0 - 65535. However, the sensor data captured has a range of values generally a lot smaller than that.
#
# We can see this if we use matplotlib to show the histogram of data. We utilize the np.ravel method to flatten out our data into a 1D array:

# %%
flattened = np.ravel(red_data)
plt.hist(flattened, bins='auto')  
plt.title("Histogram with 'auto' bins")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-1b9dd004e463> in <module>
# ----> 1 flattened = np.ravel(red_data)
#       2 plt.hist(flattened, bins='auto')
#       3 plt.title("Histogram with 'auto' bins")
#       4 plt.show()
#
# NameError: name 'np' is not defined

# %%
from rasterio.plot import show
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

fig = plt.figure(figsize= (6,6))
rasterio.plot.show(red_data)

# %%
flattened = np.ravel(red_data)
plt.hist(flattened, bins='auto')  
plt.title("Histogram with 'auto' bins")
plt.show()

# %% [markdown]
# Most of our data lives in the left hand part of this graph, though there is noisey data all along the scale. One way to mitigate this for our visualization is to "clamp" the values to some sensible min and max data: if values are below or above a given range, we set them to our desired min and max.

# %%
red_data.max()
# Out:
# 58353

# %%
red_data.min()
# Out:
# 0

# %% [markdown]
# #### Reading Min, max, median and mean pixel values from each band

# %%
import rasterio
import numpy as np
from pprint import pprint
import os

#landsat_scene_name = "LC08_L1TP_169056_20190312_20190325_01_T1"
# Reading pixel values from  red band

with rasterio.open("C:/Users/mac/Documents/Python_Rasterio/LC08_L1TP_169056_20190312_20190325_01_T1_B4.TIF") as src:
    red_band = src.read()
stats = []
stats.append({
        'min': red_band.min(),
        'mean': red_band.mean(),
        'median': np.median(red_band),
        'max': red_band.max()})

pprint(stats)
# Out:
# [{'max': 58353, 'mean': 6940.151118093377, 'median': 8973.0, 'min': 0}]

# %% [markdown]
# From the statistics, it looks like the red_band has a range of (58353), i.e., the values in the red band are in the range [0,58353].

# %% [markdown]
# #### Let's see the stat of NIR band

# %%
with rasterio.open("C:/Users/mac/Documents/Python_Rasterio/LC08_L1TP_169056_20190312_20190325_01_T1_B5.TIF") as src:
    nir_band = src.read()
stats = []
stats.append({
        'min': nir_band.min(),
        'mean': nir_band.mean(),
        'median': np.median(nir_band),
        'max': nir_band.max()})

pprint(stats)
# Out:
# [{'max': 62357, 'mean': 9922.210818360336, 'median': 12974.0, 'min': 0}]

# %% [raw]
# ##### The stat for the NIR band has a range of (62357), i.e., the values in the NIR band are in the range [0,62357].
#
# So, the range is a bit different. In some cases it is desirable to have the same range for both the bands. Let's bring them into the range [0.0,1.0] using the below equation.
#
# X' = {X-min(X)}/{max(X) - min(X)}
#
# The process of mapping an image from its inital range to [0,1] is referred to as normalization.

# %% [raw]
# redband = (redband - redband.min())/(redband.max() - redband.min())
# nirband = (nirband - nirband.min())/(nirband.max() - nirband.min())

# %% [markdown]
# ###### Now check the range of both the bands

# %%
stats = []

stats.append({
        'band': 'RED',
        'min': red_band.min(),
        'mean': red_band.mean(),
        'median': np.median(red_band),
        'max': red_band.max()})


stats.append({
        'band': 'NIR',
        'min': nir_band.min(),
        'mean': nir_band.mean(),
        'median': np.median(nir_band),
        'max': nir_band.max()})
pprint(stats)
# Out:
# [{'band': 'RED',
#   'max': 58353,
#   'mean': 6940.151118093377,
#   'median': 8973.0,
#   'min': 0},
#  {'band': 'NIR',
#   'max': 62357,
#   'mean': 9922.210818360336,
#   'median': 12974.0,
#   'min': 0}]

# %% [markdown]
# #### Calculating NDVI

# %%
nir_band = nir_band.astype(np.float64)
red_band = red_band.astype(np.float64)
ndvi = (nir_band - red_band)/(nir_band + red_band+0.0000000001) # +0.0000000001 is used here to avoid 0/0

# %% [markdown]
# ###### Visualizing the NDVI values
# We shall visualize the NDVI obtained using rasterio.plot.show() with YlGn as colormap.
# Save the NDVI image obtained for future purposes.

# %%
# %matplotlib notebook
# %matplotlib notebook

fig = plt.figure(figsize=(6,6))
rasterio.plot.show(ndvi, cmap = 'YlGn')
ndvi.min()
# Out:
# <img src="data:image/png;base64,..." width="432">
# -0.9999999999999923

# %% [markdown]
# #### Let's save the above image for future labs

# %%
src = rasterio.open('C:/Users/mac/Documents/Python_Rasterio/LC08_L1TP_169056_20190312_20190325_01_T1_B4.TIF')
kwargs = src.meta.copy()
kwargs.update({ 'dtype': rasterio.float64 })
print(kwargs)
# Out:
# {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 7601, 'height': 7761, 'count': 1, 'crs': CRS({'init': 'epsg:32637'}), 'transform': Affine(30.0, 0.0, 176085.0,
#        0.0, -30.0, 755715.0)}

# %%
with rasterio.open('C:/Users/mac/Documents/Python_Rasterio/LC08_L1TP_169056_20190312_20190325_01_T1_ndvi.TIF','w', **kwargs) as dst:
     dst.write(ndvi)

# %%
# %matplotlib inline
with rasterio.open('C:/Users/mac/Documents/Python_Rasterio/LC08_L1TP_169056_20190312_20190325_01_T1_ndvi.TIF') as src:
    fig = plt.figure(figsize = (6,6))
    rasterio.plot.show(src.read(),cmap = 'YlGn')

# %% [markdown]
# #### Analyzing NDVI image
# The NDVI values range from -1 to 1. The greener the area, the more the presence of live green vegetation. In general,
#
# Areas containing a dense vegetation will tend to have positive values (say 0.3 to 0.8)
# Clouds and snow fields will be characterized by negative values of this index.
# Free standing water tend to have very low positive or even slightly negative NDVI values,
# Soils also tend to generate small positive NDVI values (say 0.1 to 0.2).
# According to the docs for Landsat 8, those blank areas around the edges should be ignored. Many raster datasets implement this with an optional nodata value.
#
# Let's follow the above guidelines, and compare the original RGB image of the scene with the NDVI image.

# %%
# %matplotlib inline
with rasterio.open('C:/Users/mac/Documents/Python_Rasterio/LC08_L1TP_169056_20190312_20190325_01_T1_Stack.tif') as src:
    fig = plt.figure(figsize = (4,4))
    rasterio.plot.show(src.read(),cmap = 'YlGn')

# %%
import matplotlib.pyplot as plt

# %matplotlib notebook

original_image = ''
with rasterio.open('C:/Users/mac/Documents/Python_Rasterio/LC08_L1TP_169056_20190312_20190325_01_T1_Stack.tif') as data:
    original_image = data.read()
fig = plt.figure(figsize=(8,8))
a = fig.add_subplot(1,2,3)
a.set_title('Original RGB Image')
rasterio.plot.show(original_image)
#a = fig.add_subplot(1,2,2)
#a.set_title('NDVI index image')
#rasterio.plot.show(ndvi, cmap = 'YlGn')
